# %% [markdown]
# ## Predicting the alpha signal using microblogging data

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# #### A hedge fund uses 6 financial factors to predict the alpha signal in a stock. This alpha signal is used to make purchase decisions about the stock. The hedge fund now collected and tagged microblogging data for sentiment from the Social Media platform called  StockTwits’.
#
# #### StockTwits is used by people who regularly trade stocks. People on this platform tweet about stocks using the special character ‘$’ to indicate the name of the stock. These microblogs similar to tweets might contain important information about the alpha signal in a stock.
#
# #### Your goal is to build a sentiment analysis model using the tagged data. This sentiment analysis model should then be used to generate a new stock factor which together with the other stock factors should be used to predict the Alpha Signal.
#
# #### The hedge fund has anonymyzed the data, which contains 7 stock factors and an alpha signal. This alpha signal is generated using a near perfect algorithmic trading strategy. Unfortunately, the number of stock factors, collected to run that strategy, are extremely high and have to be collected from a large number of data vendors at a high price.
#
# #### Replicating the alpha signal generated from that strategy using just the 7 Stock Factors and the factor generated from sentiment analysis of the stocktwits would make the company incur significantly less costs to perform their trades.

# %% [markdown]
# #### Background
#
# #### Stocktwits:
#
# #### - Social media, the information about public feelings has become abundant. Social media is transforming like a perfect platform to share public emotions about any topic and has a significant impact on overall public opinion.
#
# #### - StockTwits is a micro-blogging application that allows users to follow and comment other user’s thoughts or share their opinions in real time.Currently, StockTwits has 1.5 million active monthly users.
#
# #### - In this project a method for predicting the alpha signal which is used to predict the stocks is developed using ,StockTwits tweets about various companies.
#
# #### - Sentiment analysis of the collected tweets is used as prediction model for finding and analyzing correlation between contents of tweets and alpha signal and then making predictions for future prices will be developed by using machine learning.

# %% [markdown]
# #### Alpha Signal:
#
# #### - Stocktwits alpha signal can be thought to be caluculated using the ,Twitter data analytics supplied by PsychSignal.com, the way that PsychSignal's technology works, is by applying a proprietary Natural Language Processing Engines to determine the bullishness and bearishness of the trading public, using the raw feeds from multiple sources like Twitter.
#
# #### - The PsychSignal dataset consistently outperforms all other sentiment analysis products because it delivers simultaneous Bull and Bear, to 2 decimal places on a scale of 0 to 4.
#
# #### - In our dataset the alpha signal ranges from the value of 1 to 4.

# %% [markdown]
# #### Bullish and Bearish:
#
# #### - The terms bullish and bearish define whether traders think that prices of an asset will rise or fall in the future. They are also used in hindsight to describe rising or falling markets. They are common trading terms in the written press.
#
# #### - Bullish: When traders are bullish about an asset, they believe that its price will rise. Bull markets feature rising prices.
# #### - Bearish: When traders are bearish about an asset, they believe that its price will fall. Bear markets feature falling prices.

# %% [markdown]
# #### Approach
#
# #### 1.] First we had to  build models using the 7 anonymized stock factors (SF1 - SF7) to predict alpha.
#
# #### 2.] We had to perform the sentiment analysis on the tweets provided in the json files .
#
# #### 3.] The visualisation about our understanding from the data and the json files that are provided.
#
# #### 4.] We had to predict the alpha signal based on the sentiment score provided in the json data alongwith the 7 anonymized stock factors (SF1 - SF7) to predict alpha.
#
# #### 5.] Build a training model on the sentiment data and then perform predictions on the test sentiment data provided to predict the sentiment score.
#
# #### 6.] Use the sentiment score from the predictions of the test sentiment data alongwith the 7 anonymized stock factors (SF1 - SF7) of the test data and predict the alpha signal.

# %% [markdown]
# ### Flow of The Project

# %% [markdown]
# #### Step 1: Data Collection
# #### - Tweets on Microsoft, Google, AAPL, are extracted from StockTwits. The company utilized Twitter's application programming interface (API) to integrate StockTwits as its own "highly graphical platform of market news, sentiment and stock-picking tools."
#
# #### - StockTwits utilized "cashtags" with the stock ticker symbol, similar to the Twitter hashtag, as a way of indexing people's thoughts and ideas about a company and the stock.
#
# #### - StockTwits allows users to communicate to Ticker Streams in real time with the use of cashtags. Users are also able to communicate directly using the "@" symbol before a username, a feature seen on Twitter.

# %% [markdown]
# #### Step 2: Data Pre-Processing
#
# #### - Stock data is collected from the 3rd of July 2018 to 31st October 2018, which is of four months. There are seven anonymous factors based on which the alpha signal of the stock is calculated.
#
# #### - Tweets consists of many acronyms, emoticons and unnecessary data like pictures and URL’s. So, tweets are pre-processed to represent correct emotions of public.
#
# #### - For pre-processing of tweets, I employed three stages of filtering:  Used string operations for removal of special characters, Tokenization and Lemmatization and stop words removal .
#
# #### 1) String operations to remove different types of special characters and emoticons and the URLs used in the tweets.
#
# #### 2) i.]Tokenization: Tweets are split into individual words. We form a list of individual words removed.Tokenization is carried out along with lemmatizer.
# #### ii.]Lemmatization : To convert words to their root form depending upon nature of the sentence they are used in. I have used WordNetLemmatizer of nltk.
#
# #### 3)Stop word Removal: Words that do not express any emotion are called Stop words. After splitting a tweet, words like a, is, the, with etc. are removed from the list of words.Stop words removal is carried out alongwith the vectorizer.

# %% [markdown]
# #### Step 3: Sentiment Analysis
#
# #### - Sentiment analysis task is very much field specific. The tweets received are examined by humans and annotated as 0 for Negative ,1 for Somewhat Negative, 2 for neutral , 3 for Somewhat positive, 4 for Positive emotions.
#
# #### - For classification of nonhuman annotated tweets, a machine learning model is trained whose features are extracted from the human annotated tweets.

# %% [markdown]
# #### Step 4 : Feature Generation:
#
# #### - In this step sentiment analysis is carried out through text classification, we use the tweets as  a set of texts and their sentiment scores as their respective labels. But we directly can't use text for our model. We need to convert these texts into some numbers or vectors of numbers.
#
# #### - Bag-of-words model(BoW ) is the simplest way of extracting features from the text. BoW converts text into the matrix of occurrence of words within a document. This model concerns about whether given words have occurred or not in the document.
#
# #### - In Term Frequency(TF), we  just count the number of words occurred in each document. The main issue with this Term Frequency is that it will give more weight to longer documents. Term frequency is basically the output of the BoW model.
#
# #### - IDF(Inverse Document Frequency) measures the amount of information a given word provides across the document. IDF is the logarithmically scaled inverse ratio of the number of documents that contain the word and the total number of documents.
#
# ####                                    idf = log(no. of documents/no. of documents containing word W)
#
# #### - TF-IDF(Term Frequency-Inverse Document Frequency) normalizes the document term matrix. It is the product of TF and IDF. If a word has a  high tf-idf in a document,then  it is most of the times occurred in given documents and must be absent in the other documents. So the words must be a signature word.

# %% [markdown]
# #### Model Building:
#
# #### - First step ,is performed by importing the MultinomialNB module and create the Multinomial Naive Bayes classifier object using MultinomialNB() function.Then, fit our model on a train set using fit() and perform prediction on the validation set using predict().
#
# #### - Second, we import the Logistic Regression module and create the Logistic Regression classifier object using LogisticRegression() function. Then, fit our model on a train set using fit() and perform preiction on the validation set using predict().
#
# #### -Then apply the model with the best output on the given test tweets dataset.

# %% [markdown]
# #### Final Step:
#
# #### 1.] We add the sentiment score provided with stock tweets set to the train dataset and do the predictions using the classification models.
#
# #### 2.] Similarly we predict the sentiment score from the test sentiment data based on the trained sentiments.Then we add the that sentiment score to the provided test data .
#
# #### 3.] In the , last step we predict the alpha signal using the merged test data , trained on the  best classification model of the merged train data.

# %% [markdown]
# #### This is the flow on which the project is performed.

# %% [markdown]
# ### Features of the dataset in .csv file

# %% [markdown]
# #### 1. Id: Index or unique identifier for a record, in the individual data file.
# #### 2. date: The date at which the factors are generated
# #### 3. ticker: The identifier through which the company is listed in the stock exchange
# #### 4. SF1 - SF7: 7 anonymized Stock Factors that can be used to predict.
# #### 5. alpha: The alpha signal generated by using a high performing algorithmic trading strategy. (range: 1 - 4)

# %% [markdown]
# ### Features of the sentiment data in .json file

# %% [markdown]
# #### stocktwit_tweet : Contains the sentiments about the stocks present in the dataset
# #### timestamp : Contains the date and time on which the sentiments were made on the Stocktwits
# #### ticker : The identifier through which the company is listed in the stock exchange
# #### sentiment_score : The score provided to the comments expressed on the Stocktwits platform.

# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing Train Data

# %%
data = pd.read_csv("train_factors-1573207730757.csv",header = 0)

# %% [markdown]
# ### Importing train JSON Data

# %%
import json
from pandas.io.json import json_normalize
with open('train_data-1573118738755.json') as f:
    d = json.load(f)
json1 = json_normalize(d['records'])
json1.head(5)

json1.to_csv('json1.csv',index=False)

# %% [markdown]
# ### Saving the json data in .csv format

# %%
json_data = pd.read_csv("json1.csv",header =0)

# %%
pd.set_option('display.max_colwidth',-1)
json_data
# Out:
#                                                                                                              stocktwit_tweet  \
# 0        $AMD going up but hesitating however chart is very stable and going upward
# 1        @inforlong @MariaGascon Despite\nChina trade war $CAT held very well 👍
# 2        $AVGO WTF?
# 3        $PH\n New Insider Filing On: \n MULLER KLAUS PETER\nTransaction Code: \n http://www.filingscanner.com/Alerts/PH.php
# 4        $FB if it bounces tommorrow do the right thing and GTFO
# ...                                                          ...
# 1039126  $CLF https://twitter.com/hrdrckminer/status/1029129019088764928?s=12
# 1039127  $AMD 🔥🔥🔥
# 1039128  $FB damn should of shorted 196 after hours to late now
# 1039129  $AMD back to the 31&#39;s
# 1039130  $AMZN Lagging other tech today.
#
#          sentiment_score                  timestamp ticker
# 0        3                2018-09-19 18:38:28+00:00  $AMD
# ...

# %% [markdown]
# ### Converting the Tweets to string data for carrying out data cleaning

# %%
json_data.stocktwit_tweet = json_data.stocktwit_tweet.apply(lambda x:str(x))

# %%
json_data
# Out:
#                                                                     stocktwit_tweet  \
# 0        $AMD going up but hesitating however chart is very stable and going upward
# 1        @inforlong @MariaGascon Despite\nChina trade war $CAT held very well 👍
# 2        $AVGO WTF?
# 3        $PH\n New Insider Filing On: \n MULLER KLAUS PETER\nTransaction Code: \n
# 4        $FB if it bounces tommorrow do the right thing and GTFO
# ...                                                          ...
# 1039126  $CLF
# 1039127  $AMD 🔥🔥🔥
# 1039128  $FB damn should of shorted 196 after hours to late now
# 1039129  $AMD back to the 31&#39;s
# 1039130  $AMZN Lagging other tech today.
#
#          sentiment_score                  timestamp ticker
# 0        3                2018-09-19 18:38:28+00:00  $AMD
# 1        3                2018-10-09 03:51:06+00:00  $CAT
# 2        2                2018-07-12 13:35:32+00:00  $AVGO
# 3        2                2018-07-19 03:32:50+00:00  $PH
# ...

# %% [markdown]
# ### Code for removing the URLs from the tweets

# %%
json_data['stocktwit_tweet'] = json_data['stocktwit_tweet'].str.replace('http\S*',"",case=False)

# %%
json_data
# Out:
#                                                                     stocktwit_tweet  \
# 0        $AMD going up but hesitating however chart is very stable and going upward
# 1        @inforlong @MariaGascon Despite\nChina trade war $CAT held very well 👍
# 2        $AVGO WTF?
# 3        $PH\n New Insider Filing On: \n MULLER KLAUS PETER\nTransaction Code: \n
# 4        $FB if it bounces tommorrow do the right thing and GTFO
# ...                                                          ...
# 1039126  $CLF
# 1039127  $AMD 🔥🔥🔥
# 1039128  $FB damn should of shorted 196 after hours to late now
# 1039129  $AMD back to the 31&#39;s
# 1039130  $AMZN Lagging other tech today.
#
#          sentiment_score                  timestamp ticker
# 0        3                2018-09-19 18:38:28+00:00  $AMD
# 1        3                2018-10-09 03:51:06+00:00  $CAT
# 2        2                2018-07-12 13:35:32+00:00  $AVGO
# 3        2                2018-07-19 03:32:50+00:00  $PH
# ...

# %% [markdown]
# ### Code to keep only the text and to remove every special character and emoticon present in the tweet

# %%
json_data.stocktwit_tweet = json_data.stocktwit_tweet.str.replace("[^a-zA-Z]", " ")
json_data.head()
# Out:
#                                                               stocktwit_tweet  \
# 0   AMD going up but hesitating however chart is very stable and going upward
# 1   inforlong  MariaGascon Despite China trade war  CAT held very well
# 2   AVGO WTF
# 3   PH  New Insider Filing On    MULLER KLAUS PETER Transaction Code
# 4   FB if it bounces tommorrow do the right thing and GTFO
#
#    sentiment_score                  timestamp ticker
# 0  3                2018-09-19 18:38:28+00:00  $AMD
# 1  3                2018-10-09 03:51:06+00:00  $CAT
# 2  2                2018-07-12 13:35:32+00:00  $AVGO
# 3  2                2018-07-19 03:32:50+00:00  $PH
# 4  3                2018-08-23 19:07:54+00:00  $FB

# %% [markdown]
# ### Code for checking the null values left in the data set

# %%
json_data.isnull().sum()
# Out:
# stocktwit_tweet    0
# sentiment_score    0
# timestamp          0
# ticker             0
# dtype: int64

# %% [markdown]
# ### Countplot to see the sentiment score

# %%
plt.figure(figsize=(10,8))
sns.countplot("sentiment_score",data = json_data)
plt.xlabel("Sentiment Score")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# ### Code for seeing the number of tickers in the json data

# %%
json_data['ticker'].unique().tolist()
# Out:
# ['$AMD',
#  '$CAT',
#  '$AVGO',
#  '$PH',
#  '$FB',
#  '$AET',
#  '$NOC',
#  '$AMZN',
#  '$NFLX',
#  '$gww',
#  '$AAPL',
#  '$ANTM',
#  '$NWL',
#  '$mu',
#  '$MU',
#  '$EIX',
#  '$amzn',
#  '$MSFT',
#  '$GE',
#  '$URI',
#  '$DUK',
#  '$LUV',
#  '$HAL',
#  '$SHLD',
#  '$COST',
#  '$BHGE',
#  '$LRCX',
#  '$AAL',
#  '$BK',
#  '$PYPL',
#  '$CMA',
#  '$LLY',
#  '$GPN',
#  '$NTAP',
#  '$STI',
#  '$DLTR',
#  '$KO',
#  '$LB',
#  '$INTC',
#  '$T',
#  '$NVDA',
#  '$GOOGL',
#  '$JNJ',
#  '$BA',
#  '$RIG',
#  '$WYND',
#  '$JCP',
#  '$NDAQ',
#  '$PEP',
#  '$AYI',
#  '$GILD',
#  '$MNK',
#  '$LMT',
#  '$EA',
#  '$BKNG',
#  '$BAC',
#  '$CELG',
#  '$EOG',
#  '$CAG',
#  '$TXN',
#  '$WU',
#  '$WDC',
#  '$APH',
#  '$MCO',
#  '$ADS',
#  '$AGN',
#  '$DVN',
#  '$HES',
#  '$CMG',
#  '$unh',
#  '$COG',
#  '$SYK',
#  '$HD',
#  '$S',
#  '$AES',
#  '$NKE',
#  '$BIIB',
#  '$JD',
#  '$ETFC',
#  '$F',
#  '$MA',
#  '$CHK',
#  '$BBT',
#  '$ADBE',
#  '$DNR',
#  '$CLF',
#  '$swk',
#  '$MCHP',
#  '$XLNX',
#  '$SWN',
# ...

# %% [markdown]
# ### Code for seeing the number of tickers and their values in the json data

# %%
for i,j in zip(json_data['ticker'].value_counts().index,json_data['ticker'].value_counts().values):
    print(i,j)
# Out:
# $AMD 163675
# $MU 82680
# $AMZN 68155
# $FB 65148
# $AAPL 49561
# $NFLX 45403
# $NVDA 20532
# $GE 19772
# $MSFT 15531
# $NKE 14785
# $CHK 11507
# $F 9918
# $T 9785
# $BAC 8396
# $CLF 8366
# $INTC 7687
# $DIS 6215
# $PYPL 6092
# $JCP 6045
# $GOOGL 5947
# $SHLD 5841
# $AVGO 5572
# $ATVI 5351
# $CELG 5341
# $WMT 4998
# $BA 4972
# $DNR 4404
# $JPM 4398
# $X 4252
# $V 4070
# $CMG 4052
# $CRM 4031
# $AMAT 4018
# $IBM 4014
# $GS 3969
# $LRCX 3446
# $GILD 3429
# $EA 3339
# $EBAY 3331
# $SBUX 3318
# $WYNN 3188
# $CAT 3018
# $GOOG 2998
# $HD 2895
# $ADBE 2802
# $UAA 2771
# $AAL 2708
# $ABBV 2635
# $LMT 2612
# $MCD 2611
# $COST 2504
# $WDC 2501
# $C 2486
# $NWL 2359
# $JNJ 2339
# $SWN 2318
# $CSCO 2234
# $M 2215
# $GM 2139
# $ENDP 2076
# $amd 2047
# $RHT 2042
# $LB 2035
# $BKNG 2000
# $QCOM 1981
# $JWN 1935
# $MA 1907
# $ISRG 1891
# $ORCL 1879
# $GME 1878
# $PFE 1840
# $WFC 1817
# $FSLR 1805
# $STZ 1794
# $MNK 1790
# $BBBY 1781
# $MS 1645
# $FCX 1642
# $VZ 1605
# $KR 1593
# $DLTR 1582
# ...

# %% [markdown]
# ### Code to lowercase the tickers

# %%
json_data['ticker'] = json_data['ticker'].str.lower()

# %%
for i,j in zip(json_data['ticker'].value_counts().index,json_data['ticker'].value_counts().values):
    print(i,j)
# Out:
# $amd 165783
# $mu 84236
# $amzn 69252
# $fb 66331
# $aapl 50731
# $nflx 46343
# $nvda 21016
# $ge 20270
# $msft 15889
# $nke 15024
# $chk 11742
# $t 10069
# $f 10031
# $bac 8603
# $clf 8437
# $intc 8044
# $dis 6410
# $pypl 6279
# $googl 6276
# $jcp 6124
# $shld 5888
# $avgo 5779
# $atvi 5524
# $celg 5472
# $wmt 5205
# $ba 5199
# $jpm 4546
# $dnr 4483
# $x 4331
# $cmg 4221
# $amat 4206
# $crm 4177
# $v 4162
# $ibm 4147
# $gs 4077
# $lrcx 3655
# $ea 3624
# $gild 3525
# $sbux 3463
# $ebay 3409
# $wynn 3395
# $goog 3220
# $cat 3133
# $adbe 3021
# $hd 3009
# $uaa 2821
# $aal 2798
# $mcd 2724
# $lmt 2710
# $abbv 2685
# $wdc 2627
# $c 2616
# $cost 2610
# $nwl 2460
# $jnj 2445
# $swn 2389
# $csco 2384
# $m 2302
# $bkng 2283
# $gm 2223
# $endp 2162
# $rht 2116
# $lb 2093
# $qcom 2092
# $ma 2040
# $pfe 1998
# $jwn 1983
# $isrg 1966
# $orcl 1926
# $gme 1920
# $fslr 1907
# $stz 1906
# $wfc 1873
# $mnk 1835
# $bbby 1820
# $fcx 1726
# $ms 1688
# $cvs 1671
# $vz 1659
# $dal 1633
# $algn 1632
# ...

# %% [markdown]
# ### Code for sorting the data based on ticker and timestamp

# %%
json_data = json_data.sort_values(by=['ticker','timestamp'])

# %% [markdown]
# ### Code for removing the dollar sign from the ticker and stock tweets

# %%
json_data['ticker'] = json_data['ticker'].str.replace("$","")
json_data['stocktwit_tweet']=json_data['stocktwit_tweet'].str.replace("$","")

# %%
json_data.head()
# Out:
#                                                                                  stocktwit_tweet  \
# 14803     AAPL Some sort of expected resistance at
# 759936   davidcastelli WAY    GO  I M a   AAPL  FAN  GO TRILLION
# 382208   Learnstocks    You did attach   AAPL chart instead of  TSLA
# 352716   macro economics   AAPL     AMZN     My Portfolio
# 527130   StayAtHomeTrader  findim   pippyRN Ever Try investing in    AAPL  amp  AMZN  Nice ROI
#
#         sentiment_score                  timestamp ticker        date  \
# 14803   1                2018-08-02 14:35:42+00:00  aapl   2018-08-02
# 759936  2                2018-08-02 17:12:59+00:00  aapl   2018-08-02
# 382208  2                2018-08-02 20:32:16+00:00  aapl   2018-08-02
# 352716  2                2018-08-02 21:59:03+00:00  aapl   2018-08-02
# 527130  3                2018-08-06 01:28:00+00:00  aapl   2018-08-06
#
#             time
# 14803   14:35:42
# 759936  17:12:59
# 382208  20:32:16
# 352716  21:59:03
# ...

# %% [markdown]
# ### Code for seperating the date and time from timestamp

# %%
json_data['date'] = pd.to_datetime(json_data['timestamp']).dt.date
json_data['time'] = pd.to_datetime(json_data['timestamp']).dt.time

# %%
json_data
# Out:
#                                                                                                                                            stocktwit_tweet  \
# 14803      AAPL Some sort of expected resistance at
# 759936    davidcastelli WAY    GO  I M a   AAPL  FAN  GO TRILLION
# 382208    Learnstocks    You did attach   AAPL chart instead of  TSLA
# 352716    macro economics   AAPL     AMZN     My Portfolio
# 527130    StayAtHomeTrader  findim   pippyRN Ever Try investing in    AAPL  amp  AMZN  Nice ROI
# ...                                                                                           ...
# 998623   Some names reporting earnings this upcoming week   BOX   BBY   TIF   CRM   DKS   EXPR   DY   LULU   AMBA   ULTA   ANF   DLTR   ZUO  Earnings
# 173793     dh vvs stocks scan  CRON   CGC   CNAT   TLRY   EIGI   AMD   ZUO
# 18783      dh in leading stocks scan  CGC   CRON   AMD   ICL   EIGI   CNAT   TLRY   ZUO
# ...

# %%
json_data.drop(["timestamp"],axis=1,inplace=True)

# %%
json_data
# Out:
#                                                                                                                                            stocktwit_tweet  \
# 14803      AAPL Some sort of expected resistance at
# 759936    davidcastelli WAY    GO  I M a   AAPL  FAN  GO TRILLION
# 382208    Learnstocks    You did attach   AAPL chart instead of  TSLA
# 352716    macro economics   AAPL     AMZN     My Portfolio
# 527130    StayAtHomeTrader  findim   pippyRN Ever Try investing in    AAPL  amp  AMZN  Nice ROI
# ...                                                                                           ...
# 998623   Some names reporting earnings this upcoming week   BOX   BBY   TIF   CRM   DKS   EXPR   DY   LULU   AMBA   ULTA   ANF   DLTR   ZUO  Earnings
# 173793     dh vvs stocks scan  CRON   CGC   CNAT   TLRY   EIGI   AMD   ZUO
# 18783      dh in leading stocks scan  CGC   CRON   AMD   ICL   EIGI   CNAT   TLRY   ZUO
# ...

# %% [markdown]
# ### Code for arranging the json data on ticker and date

# %%
json_data = json_data.sort_values(by=["ticker","date"])

# %%
json_data.head()
# Out:
#                                                                                              stocktwit_tweet  \
# 520339   A Market Positioning is Very Underweight  CrowdThnk     s Algo forecasts     chance Moving Higher
# 780362  short interest ratio of  A is      at            and short   to float is        via  sunshineave
# 684345  Here s what    Estimize analysts believe  A will report for Q       revenue  Reporting       AMC
# 914879   AgilentTechnologies has a high payout ratio of         A  A
# 75734              Short sale volume  not short interest  for  A is       via  shortvolumes
#
#         sentiment_score ticker        date      time
# 520339  2                a      2018-07-03  21:40:47
# 780362  0                a      2018-07-04  07:15:37
# 684345  2                a      2018-07-04  15:12:41
# 914879  2                a      2018-07-05  16:31:34
# 75734   1                a      2018-07-06  02:01:36

# %% [markdown]
# ### WordCloud plot to see all the words contained in the tweets

# %%
all_words = ' '.join([text for text in json_data['stocktwit_tweet']])
import wordcloud
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Words with sentiment score 2

# %%
word_ss_2 =' '.join([text for text in json_data['stocktwit_tweet'][json_data['sentiment_score']== 2]])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(word_ss_2)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Code for performing Lemmatization on train JSON data

# %%
x = json_data['stocktwit_tweet']
print(x.dtypes)
# Lemmatize with POS Tag
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
import nltk

def get_wordnet_pos(word):
    """ Map POS tag to first character lemmatize() accepts"""
    word=word.lower()
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)



lemmatizer = WordNetLemmatizer()

def word_lemma(sentence):
    return [lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in nltk.word_tokenize(sentence.lower())]

json_data["stocktwit_tweet"]=x.apply(lambda x: " ".join(word_lemma(x)))
# Out:
# object

# %%
json_data.head()
# Out:
#                                                                          stocktwit_tweet  \
# 520339  a market position be very underweight crowdthnk s algo forecast chance move high
# 780362  short interest ratio of a be at and short to float be via sunshineave
# 684345  here s what estimize analyst believe a will report for q revenue reporting amc
# 914879  agilenttechnologies have a high payout ratio of a a
# 75734   short sale volume not short interest for a be via shortvolumes
#
#         sentiment_score ticker        date      time
# 520339  2                a      2018-07-03  21:40:47
# 780362  0                a      2018-07-04  07:15:37
# 684345  2                a      2018-07-04  15:12:41
# 914879  2                a      2018-07-05  16:31:34
# 75734   1                a      2018-07-06  02:01:36

# %%
json_data.to_csv('json_cleaned.csv',index=False)

# %%
json_data.to_pickle("json_train_cleaned.pkl")

# %% [markdown]
# ### Code for importing the Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, max_features=20000, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(json_data['stocktwit_tweet'])
tfidf.shape
# Out:
# (1039131, 20000)

# %% [markdown]
# ### Splitting the data into train and validation using the tfidf vectorizer output

# %%
y = json_data['sentiment_score']

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test = train_test_split(tfidf,y,stratify=y,random_state=99,
                                                 test_size=0.3)

# %% [markdown]
# ### Code for performing Naive Bayes Classification

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_pred = clf.predict(X_test)

# %%
y_pred[0:100]
# Out:
# array([2, 3, 4, 4, 2, 4, 2, 2, 2, 2, 3, 2, 2, 2, 3, 4, 2, 3, 2, 3, 2, 2,
#        2, 2, 2, 2, 2, 4, 3, 0, 2, 3, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 3, 3, 2, 2, 3, 2, 2, 2, 4, 3, 2, 0, 2, 2, 4,
#        2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 4,
#        2, 2, 2, 2, 4, 2, 2, 2, 0, 2, 2, 2], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[  8223,   1073,  13893,   3119,   1299],
#        [   900,   7778,  20169,   5585,   1799],
#        [   915,    754, 125004,   8960,   3688],
#        [   759,   1945,  34482,  19954,   5269],
#        [   197,    167,  18171,   9265,  18372]], dtype=int64)

# %% [markdown]
# ### Code for observing the classification report of Naive Bayes Model

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.30      0.43     27607
#            1       0.66      0.21      0.32     36231
#            2       0.59      0.90      0.71    139321
#            3       0.43      0.32      0.37     62409
#            4       0.60      0.40      0.48     46172
#
#     accuracy                           0.58    311740
#    macro avg       0.61      0.43      0.46    311740
# weighted avg       0.58      0.58      0.54    311740

# %% [markdown]
# ### Importing the library for f1 metrics

# %%
from sklearn.metrics import f1_score

# %%
tfidf_vectorizer .get_feature_names()[200:210]
# Out:
# ['adap',
#  'adapt',
#  'adapter',
#  'adaptive',
#  'adavair',
#  'adbe',
#  'add',
#  'addict',
#  'addiction',
#  'addictive']

# %% [markdown]
# ### Code for f1-score of Naive Bayes Classification Model

# %%
f1score = f1_score(y_test,y_pred,average="macro")

# %%
f1score
# Out:
# 0.461504294360758

# %% [markdown]
# ### Code for performing Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='saga',multi_class='multinomial',random_state = 0,class_weight="balanced",max_iter=400,n_jobs=-1)
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=400, multi_class='multinomial', n_jobs=-1,
#                    penalty='l2', random_state=0, solver='saga', tol=0.0001,
#                    verbose=0, warm_start=False)

# %%
y_pred_lr = lr.predict(X_test)

# %%
y_pred_lr
# Out:
# array([3, 0, 4, ..., 1, 2, 4], dtype=int64)

# %%
cm = confusion_matrix(y_test,y_pred_lr)

# %%
cm
# Out:
# array([[17775,  3587,  2760,  1692,  1793],
#        [ 4659, 17525,  6339,  4839,  2869],
#        [ 6894, 11196, 96131, 17492,  7608],
#        [ 4935,  7614, 13799, 25890, 10171],
#        [ 1844,  1664,  4351,  7338, 30975]], dtype=int64)

# %% [markdown]
# ### Code for observing the classification report of Logistic Regression Model

# %%
print(classification_report(y_test,y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.64      0.56     27607
#            1       0.42      0.48      0.45     36231
#            2       0.78      0.69      0.73    139321
#            3       0.45      0.41      0.43     62409
#            4       0.58      0.67      0.62     46172
#
#     accuracy                           0.60    311740
#    macro avg       0.54      0.58      0.56    311740
# weighted avg       0.62      0.60      0.61    311740

# %% [markdown]
# ### Code for f1-score of Logistic Regression Model

# %%
f1_lr = f1_score(y_test,y_pred_lr,average="macro")

# %%
f1_lr
# Out:
# 0.5590066169552277

# %% [markdown]
# #### Logistic Regression is the model which gave the best result on the sentiment analysis

# %% [markdown]
# ####################################################################################################################

# %% [markdown]
# ### Preprocessing on test sentiment data

# %% [markdown]
# ### Importing the test JSON file

# %%
import json
from pandas.io.json import json_normalize
with open('test_data.json') as f:
    d = json.load(f)
jsontest1 = json_normalize(d['records'])
jsontest1.head(5)

jsontest1.to_csv('jsontest1.csv',index=False)

# %% [markdown]
# ### Saving the test json data in .csv format

# %%
json_test_data = pd.read_csv("jsontest1.csv",header =0)

# %%
pd.set_option('display.max_colwidth',-1)
json_test_data.head()
# Out:
#                                                                                                 stocktwit_tweet  \
# 0  $CELG nothing to be exited about
# 1  $AMD yall exhaust your buyer on first green candle,,,, byeeeeee
# 2  $AMD day traders day.
# 3  $CBS https://tenor.com/wLB8.gif
# 4  $MU weak price action so far today. Don’t be afraid to go short, it’s gonna break support and free fall soon
#
#                    timestamp ticker
# 0  2018-10-25 14:26:16+00:00  $CELG
# 1  2018-07-13 13:50:39+00:00  $AMD
# 2  2018-09-25 19:10:54+00:00  $AMD
# 3  2018-07-27 22:45:48+00:00  $CBS
# 4  2018-07-31 14:59:06+00:00  $MU

# %% [markdown]
# ### Converting the Tweets to string data for carrying out data cleaning

# %%
json_test_data.stocktwit_tweet = json_test_data.stocktwit_tweet.apply(lambda x:str(x))

# %%
json_test_data.head()
# Out:
#                                                                                                 stocktwit_tweet  \
# 0  $CELG nothing to be exited about
# 1  $AMD yall exhaust your buyer on first green candle,,,, byeeeeee
# 2  $AMD day traders day.
# 3  $CBS https://tenor.com/wLB8.gif
# 4  $MU weak price action so far today. Don’t be afraid to go short, it’s gonna break support and free fall soon
#
#                    timestamp ticker
# 0  2018-10-25 14:26:16+00:00  $CELG
# 1  2018-07-13 13:50:39+00:00  $AMD
# 2  2018-09-25 19:10:54+00:00  $AMD
# 3  2018-07-27 22:45:48+00:00  $CBS
# 4  2018-07-31 14:59:06+00:00  $MU

# %% [markdown]
# ### Code for removing the URLs from the tweets

# %%
json_test_data['stocktwit_tweet'] = json_test_data['stocktwit_tweet'].str.replace('http\S*',"",case=False)
json_test_data.head()
# Out:
#                                                                                                 stocktwit_tweet  \
# 0  $CELG nothing to be exited about
# 1  $AMD yall exhaust your buyer on first green candle,,,, byeeeeee
# 2  $AMD day traders day.
# 3  $CBS
# 4  $MU weak price action so far today. Don’t be afraid to go short, it’s gonna break support and free fall soon
#
#                    timestamp ticker
# 0  2018-10-25 14:26:16+00:00  $CELG
# 1  2018-07-13 13:50:39+00:00  $AMD
# 2  2018-09-25 19:10:54+00:00  $AMD
# 3  2018-07-27 22:45:48+00:00  $CBS
# 4  2018-07-31 14:59:06+00:00  $MU

# %% [markdown]
# ### Code to keep only the text and to remove every special character and emoticon present in the tweet

# %%
json_test_data.stocktwit_tweet = json_test_data.stocktwit_tweet.str.replace("[^a-zA-Z]", " ")
json_test_data.head()
# Out:
#                                                                                                 stocktwit_tweet  \
# 0   CELG nothing to be exited about
# 1   AMD yall exhaust your buyer on first green candle     byeeeeee
# 2   AMD day traders day
# 3   CBS
# 4   MU weak price action so far today  Don t be afraid to go short  it s gonna break support and free fall soon
#
#                    timestamp ticker
# 0  2018-10-25 14:26:16+00:00  $CELG
# 1  2018-07-13 13:50:39+00:00  $AMD
# 2  2018-09-25 19:10:54+00:00  $AMD
# 3  2018-07-27 22:45:48+00:00  $CBS
# 4  2018-07-31 14:59:06+00:00  $MU

# %% [markdown]
# ### Code for checking the null values left in the data set

# %%
json_test_data.isnull().sum()
# Out:
# stocktwit_tweet    0
# timestamp          0
# ticker             0
# dtype: int64

# %% [markdown]
# ### Code for sorting the data based on ticker and timestamp

# %%
json_test_data = json_test_data.sort_values(by=['ticker','timestamp'])
json_test_data.head()
# Out:
#                                                                                                                                 stocktwit_tweet  \
# 109686    DIS already closed         Love this company  but can make money playing both sides
# 215786   JRquiz A great example of the dry  intelligent American wit  Well done son      NKE
# 154344    aapl     today hmmm
# 131056    amzn Yes that sucks they don     t wanna break       area  always some sellers or short at that area       more difficult too
# 172993   AbeS   BobDole Yahoo  mowill  coinage  bvisse the expenses must by spiking   the outsourced Cust Svc at TaskU is charging them big   s
#
#                         timestamp  ticker
# 109686  2018-07-11 15:05:29+00:00  $$DIS
# 215786  2018-09-04 17:22:36+00:00  $$NKE
# 154344  2018-08-31 13:35:04+00:00  $$aapl
# 131056  2018-10-25 17:47:18+00:00  $$amzn
# 172993  2018-08-11 22:03:38+00:00  $$s

# %% [markdown]
# ### Code for removing the dollar sign from the ticker and stock tweets

# %%
json_test_data['ticker'] = json_test_data['ticker'].str.replace("$","")
json_test_data['stocktwit_tweet']=json_test_data['stocktwit_tweet'].str.replace("$","")
json_test_data.head()
# Out:
#                                                                                                                                 stocktwit_tweet  \
# 109686    DIS already closed         Love this company  but can make money playing both sides
# 215786   JRquiz A great example of the dry  intelligent American wit  Well done son      NKE
# 154344    aapl     today hmmm
# 131056    amzn Yes that sucks they don     t wanna break       area  always some sellers or short at that area       more difficult too
# 172993   AbeS   BobDole Yahoo  mowill  coinage  bvisse the expenses must by spiking   the outsourced Cust Svc at TaskU is charging them big   s
#
#                         timestamp ticker
# 109686  2018-07-11 15:05:29+00:00  DIS
# 215786  2018-09-04 17:22:36+00:00  NKE
# 154344  2018-08-31 13:35:04+00:00  aapl
# 131056  2018-10-25 17:47:18+00:00  amzn
# 172993  2018-08-11 22:03:38+00:00  s

# %% [markdown]
# ### Code for seperating the date and time from timestamp

# %%
json_test_data['date'] = pd.to_datetime(json_test_data['timestamp']).dt.date
json_test_data['time'] = pd.to_datetime(json_test_data['timestamp']).dt.time

# %%
json_test_data.head()
# Out:
#                                                                                                                                 stocktwit_tweet  \
# 109686    DIS already closed         Love this company  but can make money playing both sides
# 215786   JRquiz A great example of the dry  intelligent American wit  Well done son      NKE
# 154344    aapl     today hmmm
# 131056    amzn Yes that sucks they don     t wanna break       area  always some sellers or short at that area       more difficult too
# 172993   AbeS   BobDole Yahoo  mowill  coinage  bvisse the expenses must by spiking   the outsourced Cust Svc at TaskU is charging them big   s
#
#                         timestamp ticker        date      time
# 109686  2018-07-11 15:05:29+00:00  DIS    2018-07-11  15:05:29
# 215786  2018-09-04 17:22:36+00:00  NKE    2018-09-04  17:22:36
# 154344  2018-08-31 13:35:04+00:00  aapl   2018-08-31  13:35:04
# 131056  2018-10-25 17:47:18+00:00  amzn   2018-10-25  17:47:18
# ...

# %% [markdown]
# ### Code to lowercase the tickers

# %%
json_test_data['ticker'] = json_test_data['ticker'].str.lower()

# %% [markdown]
# ### Code for arranging the json data on ticker and date

# %%
json_test_data = json_test_data.sort_values(by=["ticker","date"])
json_test_data.head()
# Out:
#                                                                                                          stocktwit_tweet  \
# 82783   Here s what    Estimize analysts believe  A will report for Q       EPS  Reporting       AMC
# 224217  A new intraday low at        was just reached for  A
# 48594   B  Riley Lowers Adamis Pharmaceuticals FY     Earnings Estimates to         EPS  Previously             A
# 13912    A shows a strong growth in EPS          which is quite good
# 154800   A analysts on Estimize are expecting       YoY EPS growth for Q   down from        in Q   Reporting       AMC
#
#                         timestamp ticker        date      time
# 82783   2018-07-03 15:12:24+00:00  a      2018-07-03  15:12:24
# 224217  2018-07-03 16:05:02+00:00  a      2018-07-03  16:05:02
# 48594   2018-07-04 12:04:18+00:00  a      2018-07-04  12:04:18
# 13912   2018-07-11 05:56:03+00:00  a      2018-07-11  05:56:03
# 154800  2018-07-11 15:16:44+00:00  a      2018-07-11  15:16:44

# %% [markdown]
# ### Code for performing Lemmatization on test JSON data

# %%
x = json_test_data['stocktwit_tweet']
print(x.dtypes)
# Lemmatize with POS Tag
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
import nltk

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    word=word.lower()
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)


# 1. Init Lemmatizer
lemmatizer = WordNetLemmatizer()

def word_lemma(sentence):
    return [lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in nltk.word_tokenize(sentence.lower())]

json_test_data["stocktwit_tweet"]=x.apply(lambda x: " ".join(word_lemma(x)))
# Out:
# object

# %%
json_test_data.head()
# Out:
#                                                                           stocktwit_tweet  \
# 82783   here s what estimize analyst believe a will report for q eps reporting amc
# 224217  a new intraday low at be just reach for a
# 48594   b riley lower adamis pharmaceutical fy earnings estimate to eps previously a
# 13912   a show a strong growth in eps which be quite good
# 154800  a analyst on estimize be expect yoy eps growth for q down from in q reporting amc
#
#                         timestamp ticker        date      time
# 82783   2018-07-03 15:12:24+00:00  a      2018-07-03  15:12:24
# 224217  2018-07-03 16:05:02+00:00  a      2018-07-03  16:05:02
# 48594   2018-07-04 12:04:18+00:00  a      2018-07-04  12:04:18
# 13912   2018-07-11 05:56:03+00:00  a      2018-07-11  05:56:03
# 154800  2018-07-11 15:16:44+00:00  a      2018-07-11  15:16:44

# %%
json_test_data.to_csv('json_test_cleaned.csv',index=False)

# %% [markdown]
# ### Code for transforming the test JSON data with TF-IDF object of the train

# %%
tfidf_test = tfidf_vectorizer.transform(json_test_data["stocktwit_tweet"])

# %% [markdown]
# ### Code for performing the predictions on the test data

# %%
lr_sentiment = lr.predict(tfidf_test)

# %% [markdown]
# ### Code for storing the predicted sentiment values from the test JSON data

# %%
json_test_data["lr_sentiment"]=lr_sentiment

# %% [markdown]
# ### Code for adding the sentiment_score to the test JSON data

# %%
json_test_data.head()
# Out:
#                                                                           stocktwit_tweet  \
# 82783   here s what estimize analyst believe a will report for q eps reporting amc
# 224217  a new intraday low at be just reach for a
# 48594   b riley lower adamis pharmaceutical fy earnings estimate to eps previously a
# 13912   a show a strong growth in eps which be quite good
# 154800  a analyst on estimize be expect yoy eps growth for q down from in q reporting amc
#
#                         timestamp ticker        date      time  lr_sentiment
# 82783   2018-07-03 15:12:24+00:00  a      2018-07-03  15:12:24  2
# 224217  2018-07-03 16:05:02+00:00  a      2018-07-03  16:05:02  3
# 48594   2018-07-04 12:04:18+00:00  a      2018-07-04  12:04:18  1
# 13912   2018-07-11 05:56:03+00:00  a      2018-07-11  05:56:03  4
# 154800  2018-07-11 15:16:44+00:00  a      2018-07-11  15:16:44  1

# %%
json_test_data.to_pickle('json_test_cleaned.pkl')

# %% [markdown]
# ###########################################################################################################################

# %% [markdown]
# ### Performing the Preprocessing on the train.csv

# %%
data.head()
# Out:
#    Id      date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  1   21/08/18  $NTAP -0.628652  0.988891 -0.055714  0.774379  0.551089
# 1  2   11/10/18  $WYNN  1.315786  1.438754  0.187327  0.608933 -1.153030
# 2  3   21/08/18  $DRI  -1.141388 -1.455016  0.332755  0.674502  0.111326
# 3  4   10/07/18  $ge   -0.054839 -1.454149 -0.162267 -0.681870  0.307869
# 4  5   12/09/18  $FE   -0.686366  0.838865  0.073830  0.679024  0.329463
#
#         SF6       SF7  alpha
# 0 -1.329229 -0.995539  2
# 1  1.859441  0.730995  3
# 2 -0.478597 -1.488157  1
# 3 -0.529987  0.404172  2
# 4  1.262782 -1.024042  2

# %% [markdown]
# ### Columns of the train.csv data

# %%
data.columns
# Out:
# Index(['Id', 'date', 'ticker', 'SF1', 'SF2', 'SF3', 'SF4', 'SF5', 'SF6', 'SF7',
#        'alpha'],
#       dtype='object')

# %% [markdown]
# ### Histogram to see the Alpha Distribution

# %%
plt.figure(figsize=(8,8))
sns.countplot(data['alpha'])
plt.xlabel("Alpha")
plt.ylabel("Frequency")
plt.title("Histogram for Alpha")
plt.show()

# %% [markdown]
# ### Correlation plot of all the variables in the train data

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(),annot=False,linewidth=0.5)
plt.show()

# %% [markdown]
# ### Behavior of the alpha signal with Anonymous Factors SF 1-7

# %% [markdown]
# #### Change in alpha with Stock Factor 1

# %%
plt.scatter(data['SF1'],data['alpha'])
plt.xlabel("Stock Factor 1")
plt.ylabel("alpha")
plt.title("Change in alpha with Stock Factor 1")
plt.show()

# %%
plt.scatter(data['SF2'],data['alpha'])
plt.xlabel("Stock Factor 2")
plt.ylabel("alpha")
plt.title("Change in alpha with Stock Factor 2")
plt.show()

# %%
plt.scatter(data['SF3'],data['alpha'])
plt.xlabel("Stock Factor 3")
plt.ylabel("alpha")
plt.title("Change in alpha with Stock Factor 3")
plt.show()

# %%
plt.scatter(data['SF4'],data['alpha'])
plt.xlabel("Stock Factor 4")
plt.ylabel("alpha")
plt.title("Change in alpha with Stock Factor 4")
plt.show()

# %%
plt.scatter(data['SF5'],data['alpha'])
plt.xlabel("Stock Factor 5")
plt.ylabel("alpha")
plt.title("Change in alpha with Stock Factor 5")
plt.show()

# %%
plt.scatter(data['SF6'],data['alpha'])
plt.xlabel("Stock Factor 6")
plt.ylabel("alpha")
plt.title("Change in alpha with Stock Factor 6")
plt.show()

# %%
plt.scatter(data['SF7'],data['alpha'])
plt.xlabel("Stock Factor 7")
plt.ylabel("alpha")
plt.title("Change in alpha with Stock Factor 7")
plt.show()

# %% [markdown]
# ### Code for replacing the dollar sign with space

# %%
data['ticker']=data['ticker'].str.replace("$","")

# %% [markdown]
# ### Code for converting the date to appropriate format

# %%
data['date'] = pd.to_datetime(data['date'].astype('str'),format="%d/%m/%y")

# %%
data.head()
# Out:
#    Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  1  2018-08-21  NTAP  -0.628652  0.988891 -0.055714  0.774379  0.551089
# 1  2  2018-10-11  WYNN   1.315786  1.438754  0.187327  0.608933 -1.153030
# 2  3  2018-08-21  DRI   -1.141388 -1.455016  0.332755  0.674502  0.111326
# 3  4  2018-07-10  ge    -0.054839 -1.454149 -0.162267 -0.681870  0.307869
# 4  5  2018-09-12  FE    -0.686366  0.838865  0.073830  0.679024  0.329463
#
#         SF6       SF7  alpha
# 0 -1.329229 -0.995539  2
# 1  1.859441  0.730995  3
# 2 -0.478597 -1.488157  1
# 3 -0.529987  0.404172  2
# 4  1.262782 -1.024042  2

# %%
data['month'] = pd.to_datetime(data['date']).dt.month
data['day'] = pd.to_datetime(data['date']).dt.day
data["week"] = pd.to_datetime(data['date']).dt.week
data["weekday"] = pd.to_datetime(data['date']).dt.weekday

# %%
data.head()
# Out:
#    Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  1  2018-08-21  NTAP  -0.628652  0.988891 -0.055714  0.774379  0.551089
# 1  2  2018-10-11  WYNN   1.315786  1.438754  0.187327  0.608933 -1.153030
# 2  3  2018-08-21  DRI   -1.141388 -1.455016  0.332755  0.674502  0.111326
# 3  4  2018-07-10  ge    -0.054839 -1.454149 -0.162267 -0.681870  0.307869
# 4  5  2018-09-12  FE    -0.686366  0.838865  0.073830  0.679024  0.329463
#
#         SF6       SF7  alpha  month  day  week  weekday
# 0 -1.329229 -0.995539  2      8      21   34    1
# 1  1.859441  0.730995  3      10     11   41    3
# 2 -0.478597 -1.488157  1      8      21   34    1
# 3 -0.529987  0.404172  2      7      10   28    1
# 4  1.262782 -1.024042  2      9      12   37    2

# %% [markdown]
# ### Code for arranging the data with ticker and date

# %%
data = data.sort_values(by=['ticker','date'])

# %%
data.head()
# Out:
#           Id       date ticker       SF1       SF2       SF3       SF4  \
# 637    638   2018-07-03  A      1.915697  1.163520  0.327410  1.010603
# 11980  11981 2018-07-04  A      0.714843 -0.453898  0.054959 -0.179472
# 23821  23822 2018-07-12  A      0.579957 -0.497861  0.131184 -0.413089
# 4599   4600  2018-07-16  A      1.640079 -1.645380 -0.260885 -0.848959
# 12573  12574 2018-07-17  A     -0.754030 -1.047703  0.573857 -0.014013
#
#             SF5       SF6       SF7  alpha  month  day  week  weekday
# 637   -1.777404 -0.004284  0.975223  3      7      3    27    1
# 11980 -0.566941  0.706194  0.715049  1      7      4    27    2
# 23821 -0.644946  0.250135  0.716521  1      7      12   28    3
# 4599  -0.575099 -0.106789  2.007322  2      7      16   29    0
# 12573 -0.643502  0.020582 -0.804602  1      7      17   29    1

# %% [markdown]
# ### Code to lowercase the tickers

# %%
data['ticker'] = data['ticker'].str.lower()

# %%
data.head()
# Out:
#           Id       date ticker       SF1       SF2       SF3       SF4  \
# 637    638   2018-07-03  a      1.915697  1.163520  0.327410  1.010603
# 11980  11981 2018-07-04  a      0.714843 -0.453898  0.054959 -0.179472
# 23821  23822 2018-07-12  a      0.579957 -0.497861  0.131184 -0.413089
# 4599   4600  2018-07-16  a      1.640079 -1.645380 -0.260885 -0.848959
# 12573  12574 2018-07-17  a     -0.754030 -1.047703  0.573857 -0.014013
#
#             SF5       SF6       SF7  alpha  month  day  week  weekday
# 637   -1.777404 -0.004284  0.975223  3      7      3    27    1
# 11980 -0.566941  0.706194  0.715049  1      7      4    27    2
# 23821 -0.644946  0.250135  0.716521  1      7      12   28    3
# 4599  -0.575099 -0.106789  2.007322  2      7      16   29    0
# 12573 -0.643502  0.020582 -0.804602  1      7      17   29    1

# %%
data.to_pickle('train_data.pkl')

# %% [markdown]
# ### Code for splitting the dataset into train and validation

# %%
X = data[["SF1","SF2","SF3","SF4","SF5","SF6","SF7"]]
y = data[["alpha"]]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=351)

# %% [markdown]
# ### Code for performing Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
train_log_reg_csv = LogisticRegression(n_jobs=4, random_state=351)
# Function to get tuned model with best parameters
C=np.logspace(-5,5,10)
penalty=['l2']
solver=['sag']
multi_class_options = ['multinomial']
class_weight_options = ['balanced']
hyperparams = dict(C=C, penalty=penalty, solver=solver, multi_class=multi_class_options, class_weight=class_weight_options)

# Instantiating the GridSearchCV object:
clf = GridSearchCV(train_log_reg_csv, n_jobs=2, param_grid = hyperparams, cv = 5, verbose=0, scoring='f1_macro')

# %%
clf.fit(X_train,y_train)
# Out:
# C:\Users\Girish\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='warn',
#                                           n_jobs=4, penalty='l2',
#                                           random_state=351, solver='warn',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='warn', n_jobs=2,
# ...

# %%
y_pred = clf.predict(X_test)

# %%
y_pred_prob = clf.predict_proba(X_test)

# %%
y_pred_prob
# Out:
# array([[0.25607173, 0.25496023, 0.24522511, 0.24374293],
#        [0.24858064, 0.24861525, 0.25140864, 0.25139547],
#        [0.25006969, 0.25442168, 0.24605235, 0.24945629],
#        ...,
#        [0.25296011, 0.25216091, 0.24793317, 0.24694581],
#        [0.24646062, 0.25014493, 0.25004131, 0.25335314],
#        [0.24620627, 0.24681548, 0.25315666, 0.2538216 ]])

# %%
cm_train = confusion_matrix(y_test,y_pred)

# %%
cm_train
# Out:
# array([[ 602,  451,  353,  329],
#        [ 815, 1358,  399, 1106],
#        [ 377,  437,  684,  313],
#        [ 166,  685,  500,  337]], dtype=int64)

# %% [markdown]
# ### Code for observing the classification report of Logistic Regression Model

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.31      0.35      0.33      1735
#            2       0.46      0.37      0.41      3678
#            3       0.35      0.38      0.37      1811
#            4       0.16      0.20      0.18      1688
#
#     accuracy                           0.33      8912
#    macro avg       0.32      0.32      0.32      8912
# weighted avg       0.35      0.33      0.34      8912

# %% [markdown]
# ### Code for f1-score of Logistic Regression Model

# %%
f1_lg = f1_score(y_test,y_pred,average="macro")

# %%
f1_lg
# Out:
# 0.3201325646615532

# %% [markdown]
# ### Code for performing Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 250,max_depth = 20,criterion='entropy',random_state = 351)

rf.fit(X_train,y_train)
# Out:
# C:\Users\Girish\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=20, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=250,
#                        n_jobs=None, oob_score=False, random_state=351,
#                        verbose=0, warm_start=False)

# %%
y_pred_rf = rf.predict(X_test)

# %%
cm_rf = confusion_matrix(y_test,y_pred_rf)

# %%
cm_rf
# Out:
# array([[ 915,  335,  288,  197],
#        [  65, 3509,   51,   53],
#        [ 325,  350,  862,  274],
#        [ 118,  352,  191, 1027]], dtype=int64)

# %% [markdown]
# ### Code for observing the classification report of Random Forest Classifier Model

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.64      0.53      0.58      1735
#            2       0.77      0.95      0.85      3678
#            3       0.62      0.48      0.54      1811
#            4       0.66      0.61      0.63      1688
#
#     accuracy                           0.71      8912
#    macro avg       0.67      0.64      0.65      8912
# weighted avg       0.69      0.71      0.69      8912

# %%
f1_rf = f1_score(y_test,y_pred_rf,average='macro')

# %%
f1_rf
# Out:
# 0.6513071128778154

# %% [markdown]
# ### Code for Random Forest Classification with best hypertuned parameters

# %%
clf_RF = RandomForestClassifier(bootstrap=True, class_weight='balanced', criterion='entropy',
                                n_estimators=400, min_samples_split= 12, max_features='log2', max_depth=300, 
                                random_state=42, n_jobs=6)


best_model_RF = clf_RF.fit(X_train, y_train)

# Predict class labels for samples in test(X), using the best model:
predict_RF = best_model_RF.predict(X_test)

# Predict probabilities of class labels for samples in test(X), using the best model:
predict_prob_RF = best_model_RF.predict_proba(X_test)

# Check classification report with default threshold value of 0.5
from sklearn.metrics import classification_report
print(classification_report(y_test,predict_RF))
# Out:
# C:\Users\Girish\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#               precision    recall  f1-score   support
#
#            1       0.65      0.54      0.59      1735
#            2       0.79      0.92      0.85      3678
#            3       0.62      0.49      0.55      1811
#            4       0.62      0.65      0.63      1688
#
#     accuracy                           0.71      8912
#    macro avg       0.67      0.65      0.66      8912
# weighted avg       0.70      0.71      0.70      8912

# %%
f1_rf = f1_score(y_test,predict_RF,average="macro")

# %%
f1_rf
# Out:
# 0.6566421691023194

# %% [markdown]
# ##############################################################################################################################

# %% [markdown]
# ### Performing the Preprocessing on the test.csv

# %% [markdown]
# ### Importing the testdata.csv

# %%
test_data = pd.read_csv("test_factors.csv",header=0)

# %%
test_data.head()
# Out:
#        Id      date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  270007  21/07/18  $INTC -3.062194  1.223466  1.741714  2.279266 -1.323573
# 1  270008  05/10/18  $CTSH  0.816263 -2.184408  0.157975 -0.264743 -0.836282
# 2  270009  01/10/18  $CB    0.401281  0.091604  0.083411 -1.147041 -0.485223
# 3  270010  24/10/18  $CTAS -0.783521  1.192929  0.813831 -0.368166 -1.113656
# 4  270011  27/07/18  $intc  0.796507  0.455341  0.679032  0.354336 -1.799055
#
#         SF6       SF7
# 0 -0.274912 -4.504449
# 1  0.046276  0.826353
# 2 -0.601060  1.012811
# 3 -0.553581 -0.683803
# 4  0.126153  0.297111

# %% [markdown]
# ### Test data columns

# %%
test_data.columns
# Out:
# Index(['Id', 'date', 'ticker', 'SF1', 'SF2', 'SF3', 'SF4', 'SF5', 'SF6',
#        'SF7'],
#       dtype='object')

# %% [markdown]
# ### Code for removing the dollar sign and converting the date to aprropriate format

# %%
test_data['ticker']=test_data['ticker'].str.replace("$","")
test_data['date'] = pd.to_datetime(test_data['date'].astype('str'),format="%d/%m/%y")

# %%
test_data['month'] = pd.to_datetime(test_data['date']).dt.month
test_data['day'] = pd.to_datetime(test_data['date']).dt.day
test_data["week"] = pd.to_datetime(test_data['date']).dt.week
test_data["weekday"] = pd.to_datetime(test_data['date']).dt.weekday

# %%
test_data.head()
# Out:
#        Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  270007 2018-07-21  INTC  -3.062194  1.223466  1.741714  2.279266 -1.323573
# 1  270008 2018-10-05  CTSH   0.816263 -2.184408  0.157975 -0.264743 -0.836282
# 2  270009 2018-10-01  CB     0.401281  0.091604  0.083411 -1.147041 -0.485223
# 3  270010 2018-10-24  CTAS  -0.783521  1.192929  0.813831 -0.368166 -1.113656
# 4  270011 2018-07-27  intc   0.796507  0.455341  0.679032  0.354336 -1.799055
#
#         SF6       SF7  month  day  week  weekday
# 0 -0.274912 -4.504449  7      21   29    5
# 1  0.046276  0.826353  10     5    40    4
# 2 -0.601060  1.012811  10     1    40    0
# 3 -0.553581 -0.683803  10     24   43    2
# 4  0.126153  0.297111  7      27   30    4

# %% [markdown]
# ### Code to lowercase the tickers

# %%
test_data['ticker'] = test_data['ticker'].str.lower()

# %%
test_data.head()
# Out:
#        Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  270007 2018-07-21  intc  -3.062194  1.223466  1.741714  2.279266 -1.323573
# 1  270008 2018-10-05  ctsh   0.816263 -2.184408  0.157975 -0.264743 -0.836282
# 2  270009 2018-10-01  cb     0.401281  0.091604  0.083411 -1.147041 -0.485223
# 3  270010 2018-10-24  ctas  -0.783521  1.192929  0.813831 -0.368166 -1.113656
# 4  270011 2018-07-27  intc   0.796507  0.455341  0.679032  0.354336 -1.799055
#
#         SF6       SF7  month  day  week  weekday
# 0 -0.274912 -4.504449  7      21   29    5
# 1  0.046276  0.826353  10     5    40    4
# 2 -0.601060  1.012811  10     1    40    0
# 3 -0.553581 -0.683803  10     24   43    2
# 4  0.126153  0.297111  7      27   30    4

# %%
test_data.to_pickle('test_data.pkl')

# %% [markdown]
# ### Code for test data for predictions

# %%
X2_test = test_data[["SF1","SF2","SF3","SF4","SF5","SF6","SF7"]]

# %% [markdown]
# ### Code for performing the predictions on the test data

# %%
test_pred_RF = best_model_RF.predict(X2_test)

# %%
test_pred_RF
# Out:
# array([4, 3, 2, ..., 4, 2, 1], dtype=int64)

# %% [markdown]
# ### Storing the results for initial predictions

# %%
yPrediction_RF = best_model_RF.predict(X2_test)

yPredData = pd.DataFrame(
    {"id":test_data.Id.values,
     "alpha":yPrediction_RF
    
})
yPredData.to_csv('DipitRandom_Forest_Prediction.csv',index=False)

# %% [markdown]
# #############################################################################################################################

# %% [markdown]
# ### Merging the train dataset with the sentiment score

# %%
json_data = pd.read_pickle("json_train_cleaned.pkl")

# %%
train_data = pd.read_pickle('train_data.pkl')

# %%
json_data['date'] = pd.to_datetime(json_data['date'])

# %%
import datetime
def timedelta(x):
    x = datetime.timedelta(hours=x.hour, minutes=x.minute, seconds=x.second, microseconds=x.microsecond)
    return x
json_data['time'] = json_data['time'].apply(lambda x:timedelta(x))

# %% [markdown]
# ### Code for merging the train data with the json_train data

# %% [markdown]
# #### Syntax:
# #### new_df = pd.merge_asof(df1, df2, on='time', by='ticker')
#
# #### - A special type of merge used on the Time Series data.
#
# #### - Perform an asof merge. This is similar to a left-join except that we match on nearest key rather than equal keys.
#
# #### - Both DataFrames must be sorted by the key.
#
# #### - Optionally matches on equivalent keys with ‘by’ before searching with ‘on’.

# %%
json_data = json_data.sort_values(by=['date','ticker'])

# %%
train_data = train_data.sort_values(by=['date','ticker'])

# %%
new_df = pd.merge_asof(train_data, json_data, on='date', by='ticker')

# %%
print(data.shape)
print(new_df.shape)
# Out:
# (27006, 18)

# %%
new_df.head()
# Out:
#       Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  22097 2018-07-01  aapl  -0.703204  0.868280 -0.530265  1.926525  1.592222
# 1  18786 2018-07-01  aapl   0.457074 -0.035889  0.158807  0.226882 -0.581905
# 2  15790 2018-07-01  aep   -1.303957 -0.233951  0.045317  1.511381  0.824286
# 3  8624  2018-07-01  aes    0.744200  2.072823 -0.580341 -0.416194  0.635668
# 4  14064 2018-07-01  amgn   1.372894 -0.154942 -0.339781 -0.912614 -0.257784
#
#         SF6       SF7  alpha  month  day  week  weekday  \
# 0  0.232763 -1.620354  3      7      1    26    6
# 1  0.011648  0.219241  4      7      1    26    6
# 2  0.854370 -2.052022  2      7      1    26    6
# 3  0.182061  1.055082  4      7      1    26    6
# 4 -1.713210  1.834125  2      7      1    26    6
#
#                                                                                                    stocktwit_tweet  \
# ...

# %%
new_df.isnull().sum()
# Out:
# Id                 0
# date               0
# ticker             0
# SF1                0
# SF2                0
# SF3                0
# SF4                0
# SF5                0
# SF6                0
# SF7                0
# alpha              0
# month              0
# day                0
# week               0
# weekday            0
# stocktwit_tweet    205
# sentiment_score    205
# time               205
# dtype: int64

# %%
merged_df = new_df

# %%
type(merged_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Code for removing the unwanted columns from the merged data

# %%
merged_df.drop(['stocktwit_tweet','time'],axis=1,inplace=True)

# %% [markdown]
# ### Code for Imputing the missing values of the merged data

# %%
from sklearn.preprocessing import Imputer
import collections

imputer = Imputer(missing_values="NaN",strategy="median",axis=0)
imputer = imputer.fit(merged_df[["sentiment_score"]])
merged_df[['sentiment_score']]=imputer.transform(merged_df[['sentiment_score']])
# Out:
# C:\Users\Girish\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
merged_df.isna().sum()
# Out:
# Id                 0
# date               0
# ticker             0
# SF1                0
# SF2                0
# SF3                0
# SF4                0
# SF5                0
# SF6                0
# SF7                0
# alpha              0
# month              0
# day                0
# week               0
# weekday            0
# sentiment_score    0
# dtype: int64

# %% [markdown]
# ### Code for splitting the merged data into train and validation sets

# %%
X = merged_df[['SF1','SF2','SF3','SF4','SF5','SF6','SF7','sentiment_score']]
y = merged_df[['alpha']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %% [markdown]
# ### Code for Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr_class = LogisticRegression(solver='saga',multi_class='multinomial',random_state = 0,class_weight="balanced",max_iter=200,n_jobs=2)
lr_class.fit(X_train,y_train)
lr_pred = lr_class.predict(X_test)
cm_lr = confusion_matrix(y_test,lr_pred)
# Out:
# C:\Users\Girish\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Code for observing the classification report of the Logistic Regression

# %%
print(classification_report(y_test,lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.30      0.41      0.35      1661
#            2       0.47      0.29      0.36      3222
#            3       0.31      0.34      0.33      1694
#            4       0.20      0.27      0.23      1525
#
#     accuracy                           0.32      8102
#    macro avg       0.32      0.33      0.32      8102
# weighted avg       0.35      0.32      0.32      8102

# %%
from sklearn.metrics import f1_score
f1_lg = f1_score(y_test,lr_pred,average="macro")
f1_lg
# Out:
# 0.3152616116332774

# %% [markdown]
# ### Code for performing Random Forest Classifier with best hypertuned parameters

# %%
clf_RF = RandomForestClassifier(bootstrap=True, class_weight='balanced', criterion='entropy',
                                n_estimators=400, min_samples_split= 12, max_features='log2', max_depth=300, 
                                random_state=42, n_jobs=6)


best_model_RF = clf_RF.fit(X_train, y_train)

# Predict class labels for samples in test(X), using the best model:
predict_RF = best_model_RF.predict(X_test)

# Predict probabilities of class labels for samples in test(X), using the best model:
predict_prob_RF = best_model_RF.predict_proba(X_test)

# Check classification report with default threshold value of 0.5
from sklearn.metrics import classification_report
print(classification_report(y_test,predict_RF))
# Out:
# C:\Users\Girish\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#               precision    recall  f1-score   support
#
#            1       0.64      0.54      0.59      1661
#            2       0.80      0.92      0.85      3222
#            3       0.60      0.50      0.55      1694
#            4       0.62      0.65      0.63      1525
#
#     accuracy                           0.70      8102
#    macro avg       0.67      0.65      0.66      8102
# weighted avg       0.69      0.70      0.69      8102

# %% [markdown]
# ### Code for f1-score on Random Forest Classifier

# %%
f1_rf = f1_score(y_test,predict_RF,average='macro')
f1_rf
# Out:
# 0.656271797070388

# %% [markdown]
# ### Code for merging the test data with the json_test data

# %%
test_data = pd.read_pickle("test_data.pkl")

# %%
test_data.head()
# Out:
#        Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  270007 2018-07-21  intc  -3.062194  1.223466  1.741714  2.279266 -1.323573
# 1  270008 2018-10-05  ctsh   0.816263 -2.184408  0.157975 -0.264743 -0.836282
# 2  270009 2018-10-01  cb     0.401281  0.091604  0.083411 -1.147041 -0.485223
# 3  270010 2018-10-24  ctas  -0.783521  1.192929  0.813831 -0.368166 -1.113656
# 4  270011 2018-07-27  intc   0.796507  0.455341  0.679032  0.354336 -1.799055
#
#         SF6       SF7  month  day  week  weekday
# 0 -0.274912 -4.504449  7      21   29    5
# 1  0.046276  0.826353  10     5    40    4
# 2 -0.601060  1.012811  10     1    40    0
# 3 -0.553581 -0.683803  10     24   43    2
# 4  0.126153  0.297111  7      27   30    4

# %%
json_test_data = pd.read_pickle("json_test_cleaned.pkl")

# %%
json_test_data.dtypes
# Out:
# stocktwit_tweet    object
# timestamp          object
# ticker             object
# date               object
# time               object
# lr_sentiment       int64
# dtype: object

# %%
test_data.dtypes
# Out:
# Id         int64
# date       datetime64[ns]
# ticker     object
# SF1        float64
# SF2        float64
# SF3        float64
# SF4        float64
# SF5        float64
# SF6        float64
# SF7        float64
# month      int64
# day        int64
# week       int64
# weekday    int64
# dtype: object

# %%
json_test_data['date'] = pd.to_datetime(json_test_data['date'])

# %%
import datetime
def timedelta(x):
    x = datetime.timedelta(hours=x.hour, minutes=x.minute, seconds=x.second, microseconds=x.microsecond)
    return x
json_test_data['time'] = json_test_data['time'].apply(lambda x:timedelta(x))

# %%
json_test_data.dtypes
# Out:
# stocktwit_tweet    object
# timestamp          object
# ticker             object
# date               datetime64[ns]
# time               timedelta64[ns]
# lr_sentiment       int64
# dtype: object

# %%
json_test_data.head()
# Out:
#                                                                           stocktwit_tweet  \
# 82783   here s what estimize analyst believe a will report for q eps reporting amc
# 224217  a new intraday low at be just reach for a
# 48594   b riley lower adamis pharmaceutical fy earnings estimate to eps previously a
# 13912   a show a strong growth in eps which be quite good
# 154800  a analyst on estimize be expect yoy eps growth for q down from in q reporting amc
#
#                         timestamp ticker       date     time  lr_sentiment
# 82783   2018-07-03 15:12:24+00:00  a     2018-07-03 15:12:24  2
# 224217  2018-07-03 16:05:02+00:00  a     2018-07-03 16:05:02  3
# 48594   2018-07-04 12:04:18+00:00  a     2018-07-04 12:04:18  1
# 13912   2018-07-11 05:56:03+00:00  a     2018-07-11 05:56:03  4
# 154800  2018-07-11 15:16:44+00:00  a     2018-07-11 15:16:44  1

# %%
json_test_data = json_test_data.sort_values(by=['date','ticker'])

# %%
test_data = test_data.sort_values(by=['date','ticker'])

# %% [markdown]
# ### Code for merging the test data with the json_test data

# %%
new_df = pd.merge_asof(test_data, json_test_data, on='date', by='ticker')

# %%
print(test_data.shape)
print(new_df.shape)
# Out:
# (11575, 18)

# %%
merged_test_df = new_df

# %%
merged_test_df.head()
# Out:
#        Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  280897 2018-07-01  aal    0.597077  0.185008 -0.073816 -0.936783 -0.289364
# 1  271182 2018-07-01  alxn   0.357106 -0.349933  0.080493 -0.498629 -0.411686
# 2  281379 2018-07-01  amat   0.131374 -2.249649  0.104021  0.610359 -0.247068
# 3  280931 2018-07-01  amd    0.600957  0.295078 -0.197063  0.758286  0.052801
# 4  277816 2018-07-01  amg    0.338335 -0.731029 -0.943285 -1.731557  1.515122
#
#         SF6       SF7  month  day  week  weekday  \
# 0  0.383791  1.100410  7      1    26    6
# 1  0.084317  0.587354  7      1    26    6
# 2 -2.268079 -0.278888  7      1    26    6
# 3 -0.033375  0.123623  7      1    26    6
# 4  0.350108  1.586951  7      1    26    6
#
#                                                                                                                  stocktwit_tweet  \
# 0  short volume percent for aal be on versus on
# ...

# %% [markdown]
# ### Code for removing the unwanted columns from the merged data

# %%
merged_test_df.drop(['stocktwit_tweet','time','timestamp'],axis=1,inplace=True)

# %%
merged_test_df.head()
# Out:
#        Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  280897 2018-07-01  aal    0.597077  0.185008 -0.073816 -0.936783 -0.289364
# 1  271182 2018-07-01  alxn   0.357106 -0.349933  0.080493 -0.498629 -0.411686
# 2  281379 2018-07-01  amat   0.131374 -2.249649  0.104021  0.610359 -0.247068
# 3  280931 2018-07-01  amd    0.600957  0.295078 -0.197063  0.758286  0.052801
# 4  277816 2018-07-01  amg    0.338335 -0.731029 -0.943285 -1.731557  1.515122
#
#         SF6       SF7  month  day  week  weekday  lr_sentiment
# 0  0.383791  1.100410  7      1    26    6        0
# 1  0.084317  0.587354  7      1    26    6        0
# 2 -2.268079 -0.278888  7      1    26    6        1
# 3 -0.033375  0.123623  7      1    26    6        3
# 4  0.350108  1.586951  7      1    26    6        2

# %% [markdown]
# ### Code for test data for predictions

# %%
Xtest = merged_test_df[['SF1','SF2','SF3','SF4','SF5','SF6','SF7','lr_sentiment']]

# %%
test_rf = best_model_RF.predict(Xtest)

# %%
test_rf
# Out:
# array([1, 4, 4, ..., 2, 2, 1], dtype=int64)

# %% [markdown]
# ### Storing the Final test predictions

# %%
TestPrediction_RF = best_model_RF.predict(Xtest)

TestPredData = pd.DataFrame(
    {"id":test_data.Id.values,
     "alpha":TestPrediction_RF
    
})
TestPredData.to_csv('DipitTest.csv',index=False)

# %%
TestPrediction_RF
# Out:
# array([1, 4, 4, ..., 2, 2, 1], dtype=int64)

# %% [markdown]
# #### Conclusion:
#
# #### In both the instances on train data without sentiment scores mereged and train data with sentiment scores merged the best observations were obtained on Random Forest Classification

# %% [markdown]
# ##  **** Thank You ****
